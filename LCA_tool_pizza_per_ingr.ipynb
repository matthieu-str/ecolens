# %% [markdown]
# # Third step: comparison per ingredient

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import plotly.express as px

# %matplotlib inline

# %%
DATA_FOLDER = 'data/'

LCA_RESULTS = DATA_FOLDER + "results.csv"
LCA_COMPARISON = DATA_FOLDER + "six_meals_comparison.csv"
AGRBALYSE_CATEGORIES = DATA_FOLDER + "impact_categories.csv"
LCA_PER_INGREDIENT = DATA_FOLDER + "result_per_ingredient.csv"

results = pd.read_csv(LCA_RESULTS, delimiter = ';', usecols = [0,6,7], names = ['name', 'impact_result','unit'], header=0)
comparison = pd.read_csv(LCA_COMPARISON, delimiter = ';', usecols = [0,6,7,8], names = ['name', 'impact_result','unit', 'meal'], header = 0)
categories = pd.read_csv(AGRBALYSE_CATEGORIES, delimiter = ';', names = ['name', 'unit','normalization_factor','weighting','recommendation'], header=0)
results_per_ingredients = pd.read_csv(LCA_PER_INGREDIENT, delimiter=";", header = 0)

# %%
results_per_ingredients.head()
# Out:
#               Impact category Contribution  \
# 0  Human toxicity, non-cancer      100.00%
# 1  Human toxicity, non-cancer       48.72%
# 2  Human toxicity, non-cancer       41.53%
# 3  Human toxicity, non-cancer       04.75%
# 4  Human toxicity, non-cancer       03.69%
#
#                                              Process        Amount  Unit
# 0  Pizza, vegetables or pizza 4 seasons, at plant...  8.924770e-08  CTUh
# 1  Mozzarella cheese, from cow's milk, at plant - FR  4.347850e-08  CTUh
# 2              Cooked ham, case ready, at plant - FR  3.706390e-08  CTUh
# 3  Cooking, industrial, 1kg of cooked product (AG...  4.235500e-09  CTUh
# 4      Tomato, for processing, peeled, at plant - FR  3.290810e-09  CTUh

# %%
ingredients = list(set(results_per_ingredients["Process"] ))

for ing in ingredients:
    ex_ing = score_comparison.loc[score_comparison['meal'] == m ]
# Out:
# ['Mushroom, peeled, at processing - FR', "Mozzarella cheese, from cow's milk, at plant - FR", 'Water, municipal - FR', 'Pizza, vegetables or pizza 4 seasons, at plant - FR', 'Cooking, industrial, 1kg of cooked product (AGB 3.0)/ - FR', 'Cooked ham, case ready, at plant - FR', 'Tomato, for processing, peeled, at plant - FR', 'Wheat flour, at industrial mill - FR']

# %%
#TBC
